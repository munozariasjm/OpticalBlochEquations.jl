# %%
using 
    Serialization,
    Plots,
    StatsBase,
    UnitsToValue

# %% [markdown]
# ### CaOH RF MOT

# %%
redMOTdata = deserialize("CaOH_redMOT_data//1.2mW.jl")
times = redMOTdata[8]
x_trajectories = redMOTdata[1]
mean_x_trajectory = mean(x_trajectories)
plot(times[1], mean_x_trajectory, ylim=(-0.5,3.5))

# %%
redMOTdata = deserialize("CaOH_redMOT_data//3mW.jl")
times = redMOTdata[8]
x_trajectories = redMOTdata[1]
mean_x_trajectory = mean(x_trajectories)
plot(times[1], mean_x_trajectory, ylim=(-0.5,3.5))

# %%
redMOTdata = deserialize("CaOH_redMOT_data//11.5mW.jl")
times = redMOTdata[8]
x_trajectories = redMOTdata[1]
mean_x_trajectory = mean(x_trajectories)
plot(times[1], mean_x_trajectory, ylim=(-0.5,3.5))

# %%
redMOTdata = deserialize("CaOH_redMOT_data//1.2mW.jl")
x_trajectories = redMOTdata[1]
x_velocities = redMOTdata[5]
equilibrium_velocities = zeros(Float64,0)
for v_particle in x_velocities
   equilibrium_velocities = [equilibrium_velocities; v_particle[end - length(times[1])÷2: end]] 
end

equilibrium_positions = [traj[end] for traj ∈ x_trajectories]

v2 = std(equilibrium_positions)^2

nbins = 20
x = stephist(equilibrium_positions, normalize=:pdf, label="histogram", nbins=nbins)

hist_data = fit(Histogram, equilibrium_positions, nbins=nbins)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(Gaussian, v, fv, [1.0, 0, 1])
σ, x0, A = v_fit.param

k_B = 1.381e-23
fit_T = m*σ^2/k_B

display(σ)
display(fit_T)

plot!(v, Gaussian(v, v_fit.param))
plot!(xlim=(-4,4))
# Out:
# 0.8009033206458397
# 0.004550589067720229

# %%
redMOTdata = deserialize("CaOH_redMOT_data//3mW.jl")
x_trajectories = redMOTdata[1]
x_velocities = redMOTdata[5]
equilibrium_velocities = zeros(Float64,0)
for v_particle in x_velocities
   equilibrium_velocities = [equilibrium_velocities; v_particle[end - length(times[1])÷2: end]] 
end

equilibrium_positions = [traj[end] for traj ∈ x_trajectories]

v2 = std(equilibrium_positions)^2

nbins = 20
x = stephist(equilibrium_positions, normalize=:pdf, label="histogram", nbins=nbins)

hist_data = fit(Histogram, equilibrium_positions, nbins=nbins)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(Gaussian, v, fv, [1.0, 0, 50])
σ, x0, A = v_fit.param

k_B = 1.381e-23
fit_T = m*σ^2/k_B

display(σ)
display(fit_T)

plot!(v, Gaussian(v, v_fit.param))
plot!(xlim=(-4,4))
# Out:
# 0.955480688468396
# 0.006476662375773832

# %%
redMOTdata = deserialize("CaOH_redMOT_data//11.5mW.jl")
x_trajectories = redMOTdata[1]
x_velocities = redMOTdata[5]
equilibrium_velocities = zeros(Float64,0)
for v_particle in x_velocities
   equilibrium_velocities = [equilibrium_velocities; v_particle[end - length(times[1])÷2: end]] 
end

equilibrium_positions = [traj[end] for traj ∈ x_trajectories]

v2 = std(equilibrium_positions)^2

nbins = 20
x = stephist(equilibrium_positions, normalize=:pdf, label="histogram", nbins=nbins)

hist_data = fit(Histogram, equilibrium_positions, nbins=nbins)
hist_data.isdensity = true
v = collect(hist_data.edges[1])
dv = v[2]-v[1]
v = v[1:end-1] .+ dv/2
fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

v_fit = curve_fit(Gaussian, v, fv, [1.0, 0, 50])
σ, x0, A = v_fit.param

k_B = 1.381e-23
fit_T = m*σ^2/k_B

display(σ)
display(fit_T)

plot!(v, Gaussian(v, v_fit.param))
plot!(xlim=(-8,8))
# Out:
# 2.53260021514154
# 0.045503071128961

# %% [markdown]
# ### CaF single frequency cooling

# %%
CaF_cooling_data = deserialize("CaF_singlefrequency_data//CaF_cooling_data.jl")
times = CaF_cooling_data.times
x_velocities = CaF_cooling_data.z_velocities
;

# %%
plot(legend=false, title="temperature", xlabel="time (ms)",ylabel="T (μK)")

vs_avg = Float64[]
for i ∈ eachindex(times[1])
    vs = Float64[]
    for j in 1:500
       v = x_velocities[j][i]
       push!(vs, v)
    end
    push!(vs_avg, std(vs)^2)
end

m = @with_unit 59 "u"
k_B = 1.381e-23
plot(times[1], 1e6 * vs_avg .* (m/k_B))

# %% [markdown]
# ### CaF DC MOT (Tarbutt)

# %%
using LinearAlgebra, LsqFit

# %%
CaF_DCMOT_data = deserialize("CaF_DCMOT_Tarbutt//data.jl")
times = CaF_DCMOT_data.times
x_trajectories = CaF_DCMOT_data.x_trajectories
y_trajectories = CaF_DCMOT_data.y_trajectories
;

# %%
function project_xy(x_trajectory, y_trajectory)
    proj_traj = deepcopy(x_trajectory)
    xy_axis = (1,1,0) ./ sqrt(2)
    for i in eachindex(x_trajectory)
        x = x_trajectory[i]
        y = y_trajectory[i]
        xy = xy_axis ⋅ (x,y,0)
        proj_traj[i] = xy
    end
    proj_traj 
end
;

# %%
function survived(t_end, times, trajectories)
    _survived = Int64[]
    for i ∈ eachindex(times)
        if times[i][end] * 1e-3 ≈ t_end && abs(trajectories[i][end][1]) <= 10
            push!(_survived, i)
        end
    end
    return _survived
end
;

# %%
function center(i, trajectories)
    
    xs = [trajectory[i] for trajectory ∈ trajectories]

    hist_data = fit(Histogram, xs, nbins=10)
    hist_data.isdensity = true
    v = collect(hist_data.edges[1])
    dv = v[2]-v[1]
    v = v[1:end-1] .+ dv/2
    fv = hist_data.weights ./ (sum(hist_data.weights) * dv)

    v_fit = curve_fit(Gaussian, v, fv, [0.6, 1.0, 2])
    σ, x0, A = v_fit.param

    return x0
end
;

# %%
function Gaussian(x, p)
    σ, x0, A = p
   return A * exp.(-(x.-x0).^2/(2*σ^2)) 
end;

# %%
survived_idxs = survived(14e-3, times, x_trajectories)
;

# %%
xy_trajectories = [project_xy(x_trajectories[i], y_trajectories[i]) for i ∈ survived_idxs]
plot(times[survived_idxs[1]], [center(i, xy_trajectories) for i ∈ eachindex(times[1])], ylim=(-2,4.2), xticks=0:2:14, legend=nothing, box=:on,
    xlabel="Time (ms)",
    ylabel="Displacement (mm)",
    linewidth=3
)
